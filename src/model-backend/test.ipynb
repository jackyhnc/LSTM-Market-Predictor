# %%
import pandas as pd

# %%
df = pd.read_csv("results_predictions_2025-08-13_to_2025-11-11.csv")
df_sorted = df.reindex(df["Prediction"].abs().sort_values(ascending=False).index)

# %%
df_sorted.head(20)
# Out:
#     Ticker  Prediction
# 279     FI    0.046115
# 268     IP   -0.042759
# 447    ARE   -0.016923
# 157   NCLH    0.014215
# 441    CMG    0.012942
# 310   SMCI    0.012746
# 381    BAX    0.012507
# 7     META   -0.009622
# 464   MCHP    0.009100
# 57     CNC    0.008985
# 379    MAS    0.008033
# 202    MHK    0.006945
# 304    ZTS    0.006427
# 18     MOH    0.005865
# 451    DHI    0.005294
# 323   ORCL    0.005179
# 412    ALB    0.005113
# 353   CSGP   -0.004874
# 198    TER    0.004761
# 316    KMB    0.004593

# %%
import os

from dotenv import load_dotenv
load_dotenv()
alpaca_api_key = os.environ.get("ALPACA_API_KEY")

print(alpaca_api_key)
# Out:
# PKNFMPWQ4DSRE3TCVT2ZLIPBEA
